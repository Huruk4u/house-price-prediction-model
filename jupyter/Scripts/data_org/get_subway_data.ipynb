# %%
# 데이터 로드
from google.colab import drive

import pandas as pd

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
### 데이터 업로드 함수
def upload_data(file_name):
  rtn = pd.read_excel(file_name)
  rtn = pd.DataFrame(rtn)

  return rtn

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
station_data = upload_data("/content/drive/MyDrive/Colab Notebooks/헤도닉_집값예측/x_data/전체_도시철도역사정보_20230630.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-02bc05d29df9> in <cell line: 1>()
# ----> 1 station_data = upload_data("/content/drive/MyDrive/Colab Notebooks/헤도닉_집값예측/x_data/전체_도시철도역사정보_20230630.xlsx")
#
# <ipython-input-3-bf5153637a86> in upload_data(file_name)
#       1 ### 데이터 업로드 함수
#       2 def upload_data(file_name):
# ----> 3   rtn = pd.read_excel(file_name)
#       4   rtn = pd.DataFrame(rtn)
#       5
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
station_data.dropna(subset=['역사도로명주소'], inplace = True)
station_data = station_data[station_data['역사도로명주소'].str.contains('안양')]
station_data_coordinate = station_data[['역사명','역사도로명주소','역위도','역경도']]

# 열 이름 변경
station_data_coordinate = station_data_coordinate.rename(columns = {'역위도': '위도', '역경도': '경도'}, inplace = True)

# %%
station_data_coordinate
# Out:
#        역사명                     역사도로명주소        역위도         역경도
# 755    명학역          경기도 안양시 만안구 만안로 20  37.384435  126.935579
# 768    석수역       경기도 안양시 만안구 경수대로 1431  37.435161  126.902233
# 769    관악역  경기도 안양시 만안구 경수대로 1273번길 46  37.419578  126.908476
# 770    안양역         경기도 안양시 만안구 만안로 232  37.401929  126.922647
# 1004  인덕원역        경기도 안양시 동안구 흥안대로 529  37.401901  126.976818
# 1005   평촌역      경기도 안양시 동안구 부림로 지하 123  37.394346  126.963881
# 1006   범계역      경기도 안양시 동안구 동안로 지하 130  37.389783  126.950752
